# %%
import os
import pandas as pd
import numpy as np
import json

# %%
odi_dir='odis_json'
t20_dir='t20s_json'

# %%
the_10=['England','Australia','New Zealand','South Africa','West Indies','India','Pakistan','Afghanistan','Bangladesh','Sri Lanka']

# %%
name1="1st_Innings.csv"
name2="2nd_Innings.csv"
dir_path_men="D:/Cricket Prediction Project/ODI/ODI_MEN"
dir_path_women="D:/Cricket Prediction Project/ODI/ODI_WOMEN"

# %%
for filename in os.listdir(odi_dir):
    json_file=open(os.path.join(odi_dir,filename))
    file=json.load(json_file)
    meta_data = {
        "gender":file["info"]["gender"],
        "teams":file["info"]["teams"],
        "venue":file["info"]["venue"],
        # "date":file["info"]["dates"][0]
    }
    data_frame_first_innings={
        "delivery":[],
        "batter":[],
        "non_striker":[],
        "bowler":[],
        "run_hit":[],
        "extras":[],
        "type_of_extras":[],
        "total":[],
        "wicket":[],
        "player_dismissed":[],
        "mode_of_dismissal":[]
    }
    if(len(file["innings"])>=1):
        for i in file["innings"][0]["overs"]:
            c=1
            for j in i["deliveries"]:
                ball_no=str(i["over"])+"."+str(c)
                batter=j["batter"]
                bowler=j["bowler"]
                non_striker=j["non_striker"]
                run_hit=j["runs"]["batter"]
                extras=j["runs"]["extras"]
                type_of_extras="null"
                total=j["runs"]["total"]
                wickets=0
                player_dismissed="null"
                mode_of_dismissal="null"
                if "wickets" in j:
                    wickets=1
                    player_dismissed=j["wickets"][0]["player_out"]
                    mode_of_dismissal=j["wickets"][0]["kind"]
                if "extras" in j:
                    for k in j["extras"]:
                        type_of_extras=str(k)+" "
                data_frame_first_innings["delivery"].append(ball_no)
                data_frame_first_innings["batter"].append(batter)
                data_frame_first_innings["non_striker"].append(non_striker)
                data_frame_first_innings["bowler"].append(bowler)
                data_frame_first_innings["run_hit"].append(run_hit)
                data_frame_first_innings["extras"].append(extras)
                data_frame_first_innings["type_of_extras"].append(type_of_extras)
                data_frame_first_innings["total"].append(total)
                data_frame_first_innings["wicket"].append(wickets)
                data_frame_first_innings["player_dismissed"].append(player_dismissed)
                data_frame_first_innings["mode_of_dismissal"].append(mode_of_dismissal)
                c+=1
            
    data_frame_second_innings={
        "delivery":[],
        "batter":[],
        "non_striker":[],
        "bowler":[],
        "run_hit":[],
        "extras":[],
        "type_of_extras":[],
        "total":[],
        "wicket":[],
        "player_dismissed":[],
        "mode_of_dismissal":[]
        }
    if(len(file["innings"])>=2):
        for i in file["innings"][1]["overs"]:
            c=1
            for j in i["deliveries"]:
                ball_no=str(i["over"])+"."+str(c)
                batter=j["batter"]
                bowler=j["bowler"]
                non_striker=j["non_striker"]
                run_hit=j["runs"]["batter"]
                extras=j["runs"]["extras"]
                type_of_extras="null"
                total=j["runs"]["total"]
                wickets=0
                player_dismissed="null"
                mode_of_dismissal="null"
                if "wickets" in j:
                    wickets=1
                    player_dismissed=j["wickets"][0]["player_out"]
                    mode_of_dismissal=j["wickets"][0]["kind"]
                if "extras" in j:
                    for k in j["extras"]:
                        type_of_extras=str(k)+" "
                data_frame_second_innings["delivery"].append(ball_no)
                data_frame_second_innings["batter"].append(batter)
                data_frame_second_innings["non_striker"].append(non_striker)
                data_frame_second_innings["bowler"].append(bowler)
                data_frame_second_innings["run_hit"].append(run_hit)
                data_frame_second_innings["extras"].append(extras)
                data_frame_second_innings["type_of_extras"].append(type_of_extras)
                data_frame_second_innings["total"].append(total)
                data_frame_second_innings["wicket"].append(wickets)
                data_frame_second_innings["player_dismissed"].append(player_dismissed)
                data_frame_second_innings["mode_of_dismissal"].append(mode_of_dismissal)
                c+=1
    data1=pd.DataFrame(data_frame_first_innings)
    data2=pd.DataFrame(data_frame_second_innings)
    dir_name=str(meta_data["teams"][0]) + " vs " + str(meta_data["teams"][1]) + " " + str(filename)
    if meta_data["gender"]=="male" :
        path=os.path.join(dir_path_men,dir_name)
    else:
        path=os.path.join(dir_path_women,dir_name)
    try:
        os.mkdir(path)
        data1.to_csv(os.path.join(path,name1))
        data2.to_csv(os.path.join(path,name2))
        data=json.dumps(meta_data)
        with open(os.path.join(path,"meta_data.json"), "w") as outfile:
            outfile.write(data)
    except:
        print(dir_name+" exists twice")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9956/3692216317.py in <module>
#       1 for filename in os.listdir(odi_dir):
#       2     json_file=open(os.path.join(odi_dir,filename))
# ----> 3     file=json.load(json_file)
#       4     meta_data = {
#       5         "gender":file["info"]["gender"],
#
# c:\users\kaustabh\appdata\local\programs\python\python39\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# c:\users\kaustabh\appdata\local\programs\python\python39\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# c:\users\kaustabh\appdata\local\programs\python\python39\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\users\kaustabh\appdata\local\programs\python\python39\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# Testing the code while developement

# %%
json_file=open("odis_json/64846.json")
file=json.load(json_file)
data_frame_first_innings={
        "delivery":[],
        "batter":[],
        "non_striker":[],
        "bowler":[],
        "run_hit":[],
        "extras":[],
        "type_of_extras":[],
        "total":[],
        "wicket":[],
        "player_dismissed":[],
        "mode_of_dismissal":[]
    }
for i in file["innings"][0]["overs"]:
    k=i["over"]
    c=1
    for j in i["deliveries"]:
        ball_no=str(k)+"."+str(c)
        batter=j["batter"]
        bowler=j["bowler"]
        non_striker=j["non_striker"]
        run_hit=j["runs"]["batter"]
        extras=j["runs"]["extras"]
        type_of_extras="null"
        total=j["runs"]["total"]
        wickets=0
        player_dismissed="null"
        mode_of_dismissal="null"
        if "wickets" in j:
            wickets=1
            player_dismissed=j["wickets"][0]["player_out"]
            mode_of_dismissal=j["wickets"][0]["kind"]
        if "extras" in j:
            for k in j["extras"]:
                type_of_extras+=str(k)+" "
        data_frame_first_innings["delivery"].append(ball_no)
        data_frame_first_innings["batter"].append(batter)
        data_frame_first_innings["non_striker"].append(bowler)
        data_frame_first_innings["bowler"].append(non_striker)
        data_frame_first_innings["run_hit"].append(run_hit)
        data_frame_first_innings["extras"].append(extras)
        data_frame_first_innings["type_of_extras"].append(type_of_extras)
        data_frame_first_innings["total"].append(total)
        data_frame_first_innings["wicket"].append(wickets)
        data_frame_first_innings["player_dismissed"].append(player_dismissed)
        data_frame_first_innings["mode_of_dismissal"].append(mode_of_dismissal)
        c+=1

# %% [markdown]
# Saving the Data

# %%
data=pd.DataFrame(data_frame_first_innings)

# %%
data.head(40)
# Out:
#    delivery          batter    non_striker          bowler  run_hit  extras  \
# 0       0.1  ME Trescothick     WPUJC Vaas      AJ Strauss        0       0
# 1       0.2  ME Trescothick     WPUJC Vaas      AJ Strauss        1       0
# 2       0.3      AJ Strauss     WPUJC Vaas  ME Trescothick        0       0
# 3       0.4      AJ Strauss     WPUJC Vaas  ME Trescothick        0       0
# 4       0.5      AJ Strauss     WPUJC Vaas  ME Trescothick        0       0
# 5       0.6      AJ Strauss     WPUJC Vaas  ME Trescothick        0       0
# 6       1.1  ME Trescothick  KADM Fernando      AJ Strauss        4       0
# 7       1.2  ME Trescothick  KADM Fernando      AJ Strauss        0       0
# 8       1.3  ME Trescothick  KADM Fernando      AJ Strauss        0       0
# 9       1.4  ME Trescothick  KADM Fernando      AJ Strauss        0       0
# 10      1.5  ME Trescothick  KADM Fernando      AJ Strauss        0       0
# 11      1.6  ME Trescothick  KADM Fernando      AJ Strauss        0       0
# 12      2.1      AJ Strauss     WPUJC Vaas  ME Trescothick        0       0
# 13      2.2      AJ Strauss     WPUJC Vaas  ME Trescothick        3       0
# 14      2.3  ME Trescothick     WPUJC Vaas      AJ Strauss        0       0
# 15      2.4  ME Trescothick     WPUJC Vaas      AJ Strauss        0       0
# 16      2.5  ME Trescothick     WPUJC Vaas      AJ Strauss        0       0
# 17      2.6  ME Trescothick     WPUJC Vaas      AJ Strauss        0       0
# 18      3.1      AJ Strauss  KADM Fernando  ME Trescothick        0       0
# 19      3.2      AJ Strauss  KADM Fernando  ME Trescothick        0       0
# 20      3.3      AJ Strauss  KADM Fernando  ME Trescothick        0       0
# 21      3.4      MP Vaughan  KADM Fernando  ME Trescothick        0       0
# 22      3.5      MP Vaughan  KADM Fernando  ME Trescothick        0       0
# 23      3.6      MP Vaughan  KADM Fernando  ME Trescothick        0       0
# 24      4.1  ME Trescothick     WPUJC Vaas      MP Vaughan        0       0
# 25      4.2  ME Trescothick     WPUJC Vaas      MP Vaughan        0       0
# 26      4.3  ME Trescothick     WPUJC Vaas      MP Vaughan        0       0
# 27      4.4  ME Trescothick     WPUJC Vaas      MP Vaughan        0       0
# 28      4.5  ME Trescothick     WPUJC Vaas      MP Vaughan        0       0
# 29      4.6  ME Trescothick     WPUJC Vaas      MP Vaughan        0       0
# 30      5.1      MP Vaughan  KADM Fernando  ME Trescothick        0       0
# 31      5.2      MP Vaughan  KADM Fernando  ME Trescothick        0       0
# 32      5.3      MP Vaughan  KADM Fernando  ME Trescothick        0       0
# 33      5.4      MP Vaughan  KADM Fernando  ME Trescothick        0       0
# 34      5.5      MP Vaughan  KADM Fernando  ME Trescothick        0       0
# 35      5.6      MP Vaughan  KADM Fernando  ME Trescothick        0       0
# 36      6.1  ME Trescothick     WPUJC Vaas      MP Vaughan        0       0
# 37      6.2  ME Trescothick     WPUJC Vaas      MP Vaughan        0       0
# 38      6.3  ME Trescothick     WPUJC Vaas      MP Vaughan        4       0
# 39      6.4  ME Trescothick     WPUJC Vaas      MP Vaughan        0       0
#
#    type_of_extras  total  wicket player_dismissed  mode_of_dismissal
# 0            null      0       0             null               null
# 1            null      1       0             null               null
# 2            null      0       0             null               null
# 3            null      0       0             null               null
# 4            null      0       0             null               null
# 5            null      0       0             null               null
# 6            null      4       0             null               null
# 7            null      0       0             null               null
# 8            null      0       0             null               null
# 9            null      0       0             null               null
# 10           null      0       0             null               null
# 11           null      0       0             null               null
# 12           null      0       0             null               null
# 13           null      3       0             null               null
# 14           null      0       0             null               null
# 15           null      0       0             null               null
# 16           null      0       0             null               null
# 17           null      0       0             null               null
# 18           null      0       0             null               null
# 19           null      0       0             null               null
# 20           null      0       1       AJ Strauss  caught and bowled
# 21           null      0       0             null               null
# 22           null      0       0             null               null
# 23           null      0       0             null               null
# 24           null      0       0             null               null
# 25           null      0       0             null               null
# 26           null      0       0             null               null
# 27           null      0       0             null               null
# 28           null      0       0             null               null
# 29           null      0       0             null               null
# 30           null      0       0             null               null
# 31           null      0       0             null               null
# 32           null      0       0             null               null
# 33           null      0       0             null               null
# 34           null      0       0             null               null
# 35           null      0       0             null               null
# 36           null      0       0             null               null
# 37           null      0       0             null               null
# 38           null      4       0             null               null
# 39           null      0       1   ME Trescothick             caught

# %%
name="file"+".csv"
k="D:/Cricket Prediction Project/ODI"
data.to_csv(os.path.join(k,name))

# %%
ds={0:1,5:5}
with open('convert.txt', 'w') as convert_file:
     convert_file.write(json.dumps(ds))
